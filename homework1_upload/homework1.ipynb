# %%
import pandas as pd
from multiprocessing import Pool
from HackTool import myHackTool

# %%
dataSet = pd.read_csv("timing_noisy.csv")

# %%
with Pool() as p:
    p.map(myHackTool._processing, [blur for blur in range(0, 10)])
# Out:
# Process SpawnPoolWorker-341:
# Process SpawnPoolWorker-340:
# Process SpawnPoolWorker-339:
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'HackTool' on <module '__main__' (built-in)>
# Traceback (most recent call last):
# ...
